# %% [markdown]
# # Data preprocessing

# %%
import xml.etree.ElementTree as ET
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch

# %% [markdown]
# ## Extract for team-based data

# %% [markdown]
# 1st table

# %%
# Load and parse the XML file
tree = ET.parse("/Users/hungduong/Documents/MSBA UofU/MSBA 3rd/Soccer Analytics/Gonzaga/LMU Lions - Gonzaga Bulldogs 0-2 (Team-based).xml")
root = tree.getroot()

# Extract all instance elements
instances = root.find("ALL_INSTANCES").findall("instance")

# Collect data
rows = []
for inst in instances:
    row = {
        'ID': inst.findtext('ID'),
        'code': inst.findtext('code'),
        'start': inst.findtext('start'),
        'end': inst.findtext('end')
    }
    
    # Initialize list to collect multiple players
    players = []

    for label in inst.findall('label'):
        group = label.findtext('group')
        text = label.findtext('text')
        
        if group == '10 - Players':
            players.append(text)
        else:
            row[group] = text

    # Join player list into one column
    row['10 - Players'] = ', '.join(players)
    rows.append(row)

# Convert to DataFrame
team_data = pd.DataFrame(rows)

# List of numeric columns to convert
numeric_cols = [
    '11 - Start location X',
    '12 - Start location Y',
    '13 - Duration',
    '15 - End location X',
    '16 - End location Y'
]

# Convert them to float or int (use float to be safe with decimals)
for col in numeric_cols:
    if col in team_data.columns:
        team_data[col] = pd.to_numeric(team_data[col], errors='coerce')

# %% [markdown]
# 2nd table

# %%
# Load and parse the XML file
tree = ET.parse("/Users/hungduong/Documents/MSBA UofU/MSBA 3rd/Soccer Analytics/Gonzaga/Gonzaga Bulldogs - Pacific Tigers 2-0 (Team-based).xml")
root = tree.getroot()

# Extract all instance elements
instances = root.find("ALL_INSTANCES").findall("instance")

# Collect data
rows = []
for inst in instances:
    row = {
        'ID': inst.findtext('ID'),
        'code': inst.findtext('code'),
        'start': inst.findtext('start'),
        'end': inst.findtext('end')
    }
    
    # Initialize list to collect multiple players
    players = []

    for label in inst.findall('label'):
        group = label.findtext('group')
        text = label.findtext('text')
        
        if group == '10 - Players':
            players.append(text)
        else:
            row[group] = text

    # Join player list into one column
    row['10 - Players'] = ', '.join(players)
    rows.append(row)

# Convert to DataFrame
team_data_2 = pd.DataFrame(rows)

# List of numeric columns to convert
numeric_cols = [
    '11 - Start location X',
    '12 - Start location Y',
    '13 - Duration',
    '15 - End location X',
    '16 - End location Y'
]

# Convert them to float or int (use float to be safe with decimals)
for col in numeric_cols:
    if col in team_data_2.columns:
        team_data_2[col] = pd.to_numeric(team_data_2[col], errors='coerce')

# %% [markdown]
# 3rd table

# %%
# Load and parse the XML file
tree = ET.parse("/Users/hungduong/Documents/MSBA UofU/MSBA 3rd/Soccer Analytics/Gonzaga/Gonzaga Bulldogs - Portland Pilots 1-0 (Team-based).xml")
root = tree.getroot()

# Extract all instance elements
instances = root.find("ALL_INSTANCES").findall("instance")

# Collect data
rows = []
for inst in instances:
    row = {
        'ID': inst.findtext('ID'),
        'code': inst.findtext('code'),
        'start': inst.findtext('start'),
        'end': inst.findtext('end')
    }
    
    # Initialize list to collect multiple players
    players = []

    for label in inst.findall('label'):
        group = label.findtext('group')
        text = label.findtext('text')
        
        if group == '10 - Players':
            players.append(text)
        else:
            row[group] = text

    # Join player list into one column
    row['10 - Players'] = ', '.join(players)
    rows.append(row)

# Convert to DataFrame
team_data_3 = pd.DataFrame(rows)

# List of numeric columns to convert
numeric_cols = [
    '11 - Start location X',
    '12 - Start location Y',
    '13 - Duration',
    '15 - End location X',
    '16 - End location Y'
]

# Convert them to float or int (use float to be safe with decimals)
for col in numeric_cols:
    if col in team_data_3.columns:
        team_data_3[col] = pd.to_numeric(team_data_3[col], errors='coerce')

# %% [markdown]
# 4th table

# %%
# Load and parse the XML file
tree = ET.parse("/Users/hungduong/Documents/MSBA UofU/MSBA 3rd/Soccer Analytics/Gonzaga/Santa Clara Broncos - Gonzaga Bulldogs 2-1 (Team-based).xml")
root = tree.getroot()

# Extract all instance elements
instances = root.find("ALL_INSTANCES").findall("instance")

# Collect data
rows = []
for inst in instances:
    row = {
        'ID': inst.findtext('ID'),
        'code': inst.findtext('code'),
        'start': inst.findtext('start'),
        'end': inst.findtext('end')
    }
    
    # Initialize list to collect multiple players
    players = []

    for label in inst.findall('label'):
        group = label.findtext('group')
        text = label.findtext('text')
        
        if group == '10 - Players':
            players.append(text)
        else:
            row[group] = text

    # Join player list into one column
    row['10 - Players'] = ', '.join(players)
    rows.append(row)

# Convert to DataFrame
team_data_4 = pd.DataFrame(rows)

# List of numeric columns to convert
numeric_cols = [
    '11 - Start location X',
    '12 - Start location Y',
    '13 - Duration',
    '15 - End location X',
    '16 - End location Y'
]

# Convert them to float or int (use float to be safe with decimals)
for col in numeric_cols:
    if col in team_data_4.columns:
        team_data_4[col] = pd.to_numeric(team_data_4[col], errors='coerce')

# %% [markdown]
# 5th table

# %%
# Load and parse the XML file
tree = ET.parse("/Users/hungduong/Documents/MSBA UofU/MSBA 3rd/Soccer Analytics/Gonzaga/San Francisco Dons - Gonzaga Bulldogs 0-4 (Team-based).xml")
root = tree.getroot()

# Extract all instance elements
instances = root.find("ALL_INSTANCES").findall("instance")

# Collect data
rows = []
for inst in instances:
    row = {
        'ID': inst.findtext('ID'),
        'code': inst.findtext('code'),
        'start': inst.findtext('start'),
        'end': inst.findtext('end')
    }
    
    # Initialize list to collect multiple players
    players = []

    for label in inst.findall('label'):
        group = label.findtext('group')
        text = label.findtext('text')
        
        if group == '10 - Players':
            players.append(text)
        else:
            row[group] = text

    # Join player list into one column
    row['10 - Players'] = ', '.join(players)
    rows.append(row)

# Convert to DataFrame
team_data_5 = pd.DataFrame(rows)

# List of numeric columns to convert
numeric_cols = [
    '11 - Start location X',
    '12 - Start location Y',
    '13 - Duration',
    '15 - End location X',
    '16 - End location Y'
]

# Convert them to float or int (use float to be safe with decimals)
for col in numeric_cols:
    if col in team_data_5.columns:
        team_data_5[col] = pd.to_numeric(team_data_5[col], errors='coerce')

# %%
team_data.head(10)
# Out:
#    ID                            code      start        end  \
# 0   1                    Ball in play    6.18446  11.865952
# 1   2  Gonzaga Bulldogs - Possessions    6.18446  11.865952
# 2   3                    Ball in play  11.855952  17.686121
# 3   4         LMU Lions - Possessions  11.855952  17.686121
# 4   5                    Ball in play  18.681888  37.519108
# 5   6  Gonzaga Bulldogs - Possessions  18.681888  37.519108
# 6   7   Gonzaga Bulldogs - Set Pieces  18.681888  37.519108
# 7   8    Gonzaga Bulldogs - Throw ins  18.681888  37.519108
# 8   9                    Ball in play  37.509108  40.929843
# 9  10         LMU Lions - Possessions  37.509108  40.929843
#
#   01 - Location third 02 - Location flank 03 - End location third  \
# 0        Middle third              Center             Final third
# 1        Middle third              Center             Final third
# 2           Own third          Left flank               Own third
# 3           Own third          Left flank               Own third
# 4         Final third         Right flank             Final third
# 5         Final third         Right flank             Final third
# 6         Final third         Right flank             Final third
# 7         Final third         Right flank             Final third
# 8           Own third          Left flank               Own third
# 9           Own third          Left flank               Own third
#
#   04 - End location flank 05 - Length 06 - Number of team events  \
# 0             Right flank       Short                  4 or less
# 1             Right flank       Short                  4 or less
# 2              Left flank       Short                  4 or less
# 3              Left flank       Short                  4 or less
# 4             Right flank      Medium                        5-9
# 5             Right flank      Medium                        5-9
# 6             Right flank      Medium                        5-9
# 7             Right flank      Medium                        5-9
# 8              Left flank       Short                  4 or less
# 9              Left flank       Short                  4 or less
#
#    11 - Start location X  12 - Start location Y  13 - Duration 14 - Formation  \
# 0                   51.0                   35.0            6.0        4-1-4-1
# 1                   51.0                   35.0            6.0        4-1-4-1
# 2                   34.0                    8.0            4.0        4-3-1-2
# 3                   34.0                    8.0            4.0        4-3-1-2
# 4                   85.0                   68.0           16.0        4-1-4-1
# 5                   85.0                   68.0           16.0        4-1-4-1
# 6                   85.0                   68.0           16.0        4-1-4-1
# 7                   85.0                   68.0           16.0        4-1-4-1
# 8                   12.0                   12.0            2.0        4-3-1-2
# 9                   12.0                   12.0            2.0        4-3-1-2
#
#    15 - End location X  16 - End location Y  \
# 0                 34.0                  8.0
# 1                 34.0                  8.0
# 2                 20.0                  0.0
# 3                 20.0                  0.0
# 4                 12.0                 12.0
# 5                 12.0                 12.0
# 6                 12.0                 12.0
# 7                 12.0                 12.0
# 8                 12.0                  0.0
# 9                 12.0                  0.0
#
#                             10 - Players 08 - Transition 07 - Outcome 09 - xG
# 0           13. Le, 7. Warta, 14. Severn             NaN          NaN     NaN
# 1           13. Le, 7. Warta, 14. Severn             NaN          NaN     NaN
# 2                          19. McCulloch             NaN          NaN     NaN
# 3                          19. McCulloch             NaN          NaN     NaN
# 4  14. Severn, 13. Le, 20. Gray, 2. Chin             NaN          NaN     NaN
# 5  14. Severn, 13. Le, 20. Gray, 2. Chin             NaN          NaN     NaN
# 6  14. Severn, 13. Le, 20. Gray, 2. Chin             NaN          NaN     NaN
# 7  14. Severn, 13. Le, 20. Gray, 2. Chin             NaN          NaN     NaN
# 8               24. Myklebust, 5. Rucker             NaN          NaN     NaN
# 9               24. Myklebust, 5. Rucker             NaN          NaN     NaN

# %%
for code in team_data['code'].unique():
    print(code)
# Out:
# Ball in play
# Gonzaga Bulldogs - Possessions
# LMU Lions - Possessions
# Gonzaga Bulldogs - Set Pieces
# Gonzaga Bulldogs - Throw ins
# Gonzaga Bulldogs - Open play attacks
# Gonzaga Bulldogs - Crosses
# LMU Lions - Goalkeeper distributions
# LMU Lions - Highlights
# LMU Lions - Open play attacks
# LMU Lions - Shots
# LMU Lions - Set Pieces
# LMU Lions - Corners
# LMU Lions - Crosses
# LMU Lions - Throw ins
# Gonzaga Bulldogs - Goalkeeper distributions
# Gonzaga Bulldogs - Shots
# Gonzaga Bulldogs - Highlights
# Gonzaga Bulldogs - Goals
# Gonzaga Bulldogs - Corners
# LMU Lions - Free kicks
# LMU Lions - Counterattacks
# Gonzaga Bulldogs - Free kicks
# Periods

# %% [markdown]
# ## Extract for player-based data

# %%
# Load XML
tree = ET.parse("/Users/hungduong/Documents/MSBA UofU/MSBA 3rd/Soccer Analytics/Gonzaga/LMU Lions - Gonzaga Bulldogs 0-2 (Player-based).xml")
root = tree.getroot()

# Prepare list for rows
data = []

# Iterate over each instance
for inst in root.findall('.//instance'):
    row = {}
    row['ID'] = int(inst.findtext('ID'))
    row['Player Code'] = inst.findtext('code')
    row['Start Time'] = float(inst.findtext('start'))
    row['End Time'] = float(inst.findtext('end'))

    # Extract all <text> labels
    labels = [label.findtext('text') for label in inst.findall('label')]
    if labels:
        row['Action Type'] = labels[0]                   # Primary label
        row['Additional Labels'] = ', '.join(labels[1:]) # Others (if any)
    else:
        row['Action Type'] = None
        row['Additional Labels'] = ''

    data.append(row)

# Convert to DataFrame
player_data = pd.DataFrame(data)

# %%
pd.set_option('display.max_colwidth', None)
player_data.head(10)
# Out:
#    ID    Player Code  Start Time   End Time Action Type  \
# 0   1         13. Le    3.184460   8.184460        Pass
# 1   2       7. Warta    4.770350  11.855952        Pass
# 2   3  19. McCulloch    9.855952  13.855952        Duel
# 3   4     14. Severn    9.855952  13.855952        Duel
# 4   5  19. McCulloch   11.577991  15.577991        Duel
# 5   6     14. Severn   11.577991  15.577991        Duel
# 6   7     14. Severn   17.681888  21.681888    Throw in
# 7   8         13. Le   19.907523  26.613645        Pass
# 8   9       20. Gray   23.613645  29.040995        Pass
# 9  10         13. Le   26.040995  32.643144        Pass
#
#                                          Additional Labels
# 0                       Forward pass, Short or medium pass
# 1  Lateral pass, Pass to final third, Short or medium pass
# 2                    Defensive duel, Ground duel, Recovery
# 3                        Ground duel, Loss, Offensive duel
# 4                              Ground duel, Offensive duel
# 5                              Defensive duel, Ground duel
# 6
# 7                       Lateral pass, Short or medium pass
# 8                       Lateral pass, Short or medium pass
# 9                          Back pass, Short or medium pass

# %%
print(len(player_data))
# Data missingness
print(player_data.isna().count())
# Data types?
player_data.dtypes
# Out:
# 1678
# ID                   1678
# Player Code          1678
# Start Time           1678
# End Time             1678
# Action Type          1678
# Additional Labels    1678
# dtype: int64
# ID                     int64
# Player Code           object
# Start Time           float64
# End Time             float64
# Action Type           object
# Additional Labels     object
# dtype: object

# %% [markdown]
# Add optional team column for player_data (chatgpt this real quick)

# %%
lmu_players = [
    "1. Hoover", "16. Schaefer", "6. Watkins", "24. Myklebust", "5. Rucker",
    "10. Winter", "23. Land", "19. McCulloch", "9. Groves", "7. Harrington", "4. Dobbs",
    "15. Lynch", "30. Smith"
]

gonzaga_players = [
    "0. Towne", "2. Chin", "4. Werner", "10. Lester", "7. Warta", "13. Le",
    "14. Severn", "20. Gray", "21. Rigg", "11. Garcia", "19. Alexander",
    "17. Sicilia", "3. Jones", "5. Boyden", "28. Todd", "22. Parker",
    "12. Ewers", "9. Tonthat"
]

player_to_team = {p: "LMU" for p in lmu_players}
player_to_team.update({p: "Gonzaga" for p in gonzaga_players})

player_data['Team'] = player_data['Player Code'].map(player_to_team)

# %%
player_data.head()
# Out:
#    ID    Player Code  Start Time   End Time Action Type  \
# 0   1         13. Le    3.184460   8.184460        Pass
# 1   2       7. Warta    4.770350  11.855952        Pass
# 2   3  19. McCulloch    9.855952  13.855952        Duel
# 3   4     14. Severn    9.855952  13.855952        Duel
# 4   5  19. McCulloch   11.577991  15.577991        Duel
#
#                                          Additional Labels     Team
# 0                       Forward pass, Short or medium pass  Gonzaga
# 1  Lateral pass, Pass to final third, Short or medium pass  Gonzaga
# 2                    Defensive duel, Ground duel, Recovery      LMU
# 3                        Ground duel, Loss, Offensive duel  Gonzaga
# 4                              Ground duel, Offensive duel      LMU

# %% [markdown]
# Available actions of player_data in Action Type

# %%
for action in player_data['Action Type'].dropna().unique():
    print(action)
# Out:
# Pass
# Duel
# Throw in
# Touch
# Interception
# Shot
# Shot against
# Corner
# Goal kick
# Infraction
# Free kick
# Clearance
# Acceleration
# Goalkeeper exit
# Offside

# %% [markdown]
# # Analytics

# %% [markdown]
# ## Corners

# %% [markdown]
# Filter for corner kicks in team_data

# %%
combined_df = pd.concat([team_data_2, team_data, team_data_3, team_data_4, team_data_5], ignore_index=True)


team_corners = combined_df[combined_df['code'].str.contains('Gonzaga Bulldogs - Corners')]
pd.set_option('display.max_colwidth', None)
team_corners.tail()
# Out:
#         ID                        code        start          end  \
# 5296   220  Gonzaga Bulldogs - Corners   909.338601   912.336202
# 5472   396  Gonzaga Bulldogs - Corners  1724.033858  1731.059659
# 5587   511  Gonzaga Bulldogs - Corners  2284.466159  2289.236498
# 6094  1018  Gonzaga Bulldogs - Corners  4511.786707  4514.520095
# 6123  1047  Gonzaga Bulldogs - Corners  4674.136111  4680.128016
#
#      01 - Location third 02 - Location flank 03 - End location third  \
# 5296         Final third          Left flank             Final third
# 5472         Final third         Right flank             Final third
# 5587         Final third          Left flank             Final third
# 6094         Final third         Right flank             Final third
# 6123         Final third          Left flank             Final third
#
#      04 - End location flank 05 - Length 06 - Number of team events  \
# 5296                  Center       Short                  4 or less
# 5472                  Center       Short                  4 or less
# 5587                  Center       Short                  4 or less
# 6094                  Center       Short                  4 or less
# 6123                  Center       Short                  4 or less
#
#       11 - Start location X  12 - Start location Y  13 - Duration  \
# 5296                  105.0                    0.0            2.0
# 5472                  105.0                   68.0            5.0
# 5587                  105.0                    0.0            3.0
# 6094                  105.0                   68.0            1.0
# 6123                  105.0                    0.0            1.0
#
#      14 - Formation  15 - End location X  16 - End location Y  \
# 5296        4-2-3-1                  3.0                 33.0
# 5472        4-2-3-1                105.0                 27.0
# 5587        4-2-3-1                 12.0                 30.0
# 6094        4-2-3-1                  5.0                 29.0
# 6123        4-2-3-1                 98.0                 35.0
#
#                10 - Players 08 - Transition 07 - Outcome           09 - xG
# 5296   14. Severn, 21. Rigg             NaN          NaN               NaN
# 5472  13. Le, 19. Alexander             NaN         Shot  from 0.1 to 0.35
# 5587     13. Le, 22. Parker             NaN          NaN               NaN
# 6094                 13. Le             NaN          NaN               NaN
# 6123    13. Le, 17. Sicilia             NaN         Goal  from 0.1 to 0.35

# %% [markdown]
# Further filter by outcome for visualization

# %%
# Filter by outcome
corners_goal = team_corners[team_corners['07 - Outcome'] == 'Goal']
corners_shot = team_corners[team_corners['07 - Outcome'] == 'Shot']
corners_other = team_corners[
    (team_corners['07 - Outcome'] != 'Goal') & 
    (team_corners['07 - Outcome'] != 'Shot')
]
# Draw pitch
pitch = Pitch(
    pitch_length=105, pitch_width=68, pitch_type='uefa',
    pitch_color='grass', stripe=True, goal_type='box',
    #half=True, 
    label=True, axis=True, tick=True
)
fig, ax = pitch.draw()

# Plot Goal events in red
ax.scatter(
    corners_goal['15 - End location X'],
    corners_goal['16 - End location Y'],
    c='red', s=100, edgecolors='white', label='Goal'
)

# Plot Shot events in black
ax.scatter(
    corners_shot['15 - End location X'],
    corners_shot['16 - End location Y'],
    c='black', s=100, edgecolors='white', label='Shot'
)

# Plot all other events in white
ax.scatter(
    corners_other['15 - End location X'],
    corners_other['16 - End location Y'],
    c='white', s=100, edgecolors='gray', label='Other'
)

# Add legend and show
plt.legend()
plt.show()

# %%
# Who parricipated in corner kicks the most?
team_corners['10 - Players'].str.split(',')\
    .explode().str.strip()\
    .value_counts()\
    .plot(kind='bar', figsize=(10, 5))
# Out:
# <Axes: xlabel='10 - Players'>

# %% [markdown]
# ## Goal kicks

# %%
team_keep_distribution = combined_df[(combined_df['code']=='Gonzaga Bulldogs - Goalkeeper distributions')]

# Draw pitch
pitch = Pitch(
    pitch_length=105, pitch_width=68, pitch_type='uefa',
    pitch_color='grass', stripe=True, goal_type='box',
    #half=True, 
    label=True, axis=True, tick=True
)
fig, ax = pitch.draw()

# Draw arrows
pitch.arrows(
    xstart=team_keep_distribution['11 - Start location X'],
    ystart=team_keep_distribution['12 - Start location Y'],
    xend=team_keep_distribution['15 - End location X'],
    yend=team_keep_distribution['16 - End location Y'],
    color='orange',
    ax=ax,
    width=2,
    headwidth=4,
    alpha=0.6,
    zorder=3
)

plt.title("Gonzaga Keeper Distribution Arrows", fontsize=14)
plt.show()

# %%
# Extract coordinates
x_start = team_keep_distribution['11 - Start location X']
y_start = team_keep_distribution['12 - Start location Y']
x_end = team_keep_distribution['15 - End location X']
y_end = team_keep_distribution['16 - End location Y']

# Set up the pitch
pitch = Pitch(
    pitch_length=105, pitch_width=68, pitch_type='uefa',
    pitch_color='grass', stripe=True, goal_type='box',
    label=True, axis=True, tick=True
)

fig, ax = pitch.draw(figsize=(8, 5))

# Plot heatmap of start locations
bin_stat = pitch.bin_statistic(x_end, y_end, statistic='count', bins=(20, 15))
pitch.heatmap(bin_stat, ax=ax, cmap='coolwarm', alpha=0.6)

# Optional: overlay arrows (lighter and less prominent)
pitch.arrows(
    xstart=x_start,
    ystart=y_start,
    xend=x_end,
    yend=y_end,
    color='black',
    ax=ax,
    width=1.5,
    headwidth=3,
    alpha=0.1,   # Lower alpha to avoid clutter
    zorder=2
)

# Title
plt.title("Gonzaga Keeper Distribution Heatmap (End Locations)", fontsize=14)
plt.show()

# %%
team_keep_distribution['10 - Players'].str.split(',')\
    .explode().str.strip()\
    .value_counts()\
    .plot(kind='bar', figsize=(10, 5))
# Out:
# <Axes: xlabel='10 - Players'>

# %%
# Mapping for 105x68 pitch
third_to_x = {
    'Own third': 17.5,
    'Middle third': 52.5,
    'Final third': 87.5
}

flank_to_y = {
    'Left flank': 11.33,
    'Center': 34.0,
    'Right flank': 56.67
}

# Map labels to coordinates
team_keep_distribution['end_x'] = team_keep_distribution['03 - End location third'].map(third_to_x)
team_keep_distribution['end_y'] = team_keep_distribution['04 - End location flank'].map(flank_to_y)

# Drop rows where mapping failed (NaN)
team_keep_distribution = team_keep_distribution.dropna(subset=['end_x', 'end_y'])

# Create pitch
pitch = Pitch(pitch_length=105, pitch_width=68, line_color='black')
fig, ax = pitch.draw()

# Bin statistic (matching thirds/flanks)
bin_stat = pitch.bin_statistic(
    team_keep_distribution['end_x'],
    team_keep_distribution['end_y'],
    statistic='count',
    bins=(3, 3)
)

# Plot heatmap
pcm = pitch.heatmap(bin_stat, ax=ax, cmap='Reds', edgecolors='black')

# Add colorbar
cbar = plt.colorbar(pcm, ax=ax)
cbar.set_label('Number of events')

plt.show()
# Out:
# /var/folders/hd/fbf93pws5pn1ycb22tw5k1240000gn/T/ipykernel_2671/1828311421.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_keep_distribution['end_x'] = team_keep_distribution['03 - End location third'].map(third_to_x)
# /var/folders/hd/fbf93pws5pn1ycb22tw5k1240000gn/T/ipykernel_2671/1828311421.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_keep_distribution['end_y'] = team_keep_distribution['04 - End location flank'].map(flank_to_y)

# %%
combined_df['03 - End location third'].unique()
# Out:
# array(['Final third', 'Own third', 'Middle third', nan], dtype=object)

# %%
combined_df['04 - End location flank'].unique()
# Out:
# array(['Center', 'Left flank', 'Right flank', nan], dtype=object)

# %%
# Load and parse the XML file
xml_file = '/Users/hungduong/Documents/MSBA UofU/MSBA 3rd/Soccer Analytics/Gonzaga/gonzaga-bulldogs_player-events_10-11-2024_lmu-lions-gonzaga-bulldogs.xml'
tree = ET.parse(xml_file)
root = tree.getroot()

# Extract all <instance> elements
instances = root.find("ALL_INSTANCES").findall("instance")

# Parse each instance
rows = []
for inst in instances:
    row = {
        'ID': inst.findtext('ID'),
        'start': inst.findtext('start'),
        'end': inst.findtext('end'),
        'code': inst.findtext('code'),  # contains player number and name
    }
    
    # Extract all labels (can be multiple, e.g., "Passes", "Attacking duels")
    labels = [label.findtext('text') for label in inst.findall('label')]
    row['labels'] = ', '.join(labels)
    
    rows.append(row)

# Convert to DataFrame
df = pd.DataFrame(rows)

# Clean up 'code' column: split player number and name
df[['Player Number', 'Player Name']] = df['code'].str.extract(r'\((\d+)\)\s+(.*)')

# Reorder columns
df = df[['ID', 'start', 'end', 'Player Number', 'Player Name', 'labels']]

# Convert numeric columns
df[['ID', 'start', 'end']] = df[['ID', 'start', 'end']].astype(int)

# View the result
df.head(50)
# Out:
#     ID  start  end Player Number   Player Name             labels
# 0    1      1   35            13         C. Le             Passes
# 1    2      2   13             7      E. Warta             Passes
# 2    3      6   17            14     A. Severn    Attacking duels
# 3    4      8   19            14     A. Severn    Defending duels
# 4    5     14   25            14     A. Severn          Throw-ins
# 5    6     21   32            20       H. Gray             Passes
# 6    7     27   38            14     A. Severn             Passes
# 7    8     28   39             2       L. Chin  Long-range passes
# 8    9     38   49             2       L. Chin          Throw-ins
# 9   10     40   51            21       K. Rigg    Attacking duels
# 10  11     43   54            14     A. Severn           Recovery
# 11  12     43   54            14     A. Severn     1 vs 1 Defense
# 12  13     47   58            13         C. Le             Passes
# 13  14     52   63            19  P. Alexander              Cross
# 14  15     68   79            20       H. Gray    Loose ball duel
# 15  16     76   87            11     M. Garcia      Interceptions
# 16  17     86   97            14     A. Severn      Interceptions
# 17  18     94  105            19  P. Alexander             Passes
# 18  19     96  107             4     M. Werner             Passes
# 19  20    100  111             7      E. Warta             Passes
# 20  21    108  119            19  P. Alexander      Interceptions
# 21  22    112  123             4     M. Werner    Defending duels
# 22  23    115  126             0      L. Towne              Saves
# 23  24    152  163             4     M. Werner       Aerial duels
# 24  25    159  170            14     A. Severn      Interceptions
# 25  26    178  189             7      E. Warta      Interceptions
# 26  27    178  189             7      E. Warta             Passes
# 27  28    180  191            10     O. Lester             Passes
# 28  29    182  193             2       L. Chin             Passes
# 29  30    191  202            19  P. Alexander      Interceptions
# 30  31    191  202            19  P. Alexander             Passes
# 31  32    198  209            11     M. Garcia             Passes
# 32  33    200  211            21       K. Rigg    Loose ball duel
# 33  34    247  258            20       H. Gray      Interceptions
# 34  35    261  272            11     M. Garcia      Interceptions
# 35  36    261  272            11     M. Garcia             Passes
# 36  37    270  281             4     M. Werner             Passes
# 37  38    272  283             4     M. Werner    Attacking duels
# 38  39    274  285             4     M. Werner           Recovery
# 39  40    274  285             4     M. Werner     1 vs 1 Defense
# 40  41    277  288             2       L. Chin     1 vs 1 Defense
# 41  42    279  290             2       L. Chin      Interceptions
# 42  43    335  346             0      L. Towne      Distributions
# 43  44    342  353             4     M. Werner             Passes
# 44  45    352  363            10     O. Lester    Attacking duels
# 45  46    358  369            10     O. Lester    Defending duels
# 46  47    384  395             2       L. Chin             Passes
# 47  48    390  401             7      E. Warta             Passes
# 48  49    413  424             0      L. Towne      Distributions
# 49  50    421  432            19  P. Alexander             Passes

# %%
df['labels'].unique()
# Out:
# array(['Passes', 'Attacking duels', 'Defending duels', 'Throw-ins',
#        'Long-range passes', 'Recovery', '1 vs 1 Defense', 'Cross',
#        'Loose ball duel', 'Interceptions', 'Saves', 'Aerial duels',
#        'Distributions', 'Shots', '1VS1 and dribbling', 'Opportunity',
#        'Link up play', 'Fouls', 'Through passes', 'Under pressure',
#        'Clearances', 'Shot off target', 'Accelerations',
#        'Goal - Left Foot', 'Corner kick', 'Reflexes',
#        'Goalkeeper leaving line', 'Winning fouls', 'Free kick',
#        'Goal - Head', 'Head Shot', 'Aggressiveness', 'Smart passes',
#        'Free kick cross', 'Offsides', 'First half start',
#        'Second half start', 'First half end', 'Second half end'],
#       dtype=object)

# %%
df[(df['Player Name']=='L.Towne')&]
# Out:
#   Cell In[25], line 1
#     df[(df['Player Name']=='L.Towne')&]
#                                       ^
# SyntaxError: invalid syntax

# %%
team_keep_distribution_indices = team_keep_distribution.index
subset_rows= []
for idx in team_keep_distribution_indices:
    next_rows = team_data.loc[idx:idx+5]
    subset_rows.append(next_rows)

team_keep_distribution_next5 = pd.concat(subset_rows)
team_keep_distribution_next5.head(10)
# Out:
#       ID                                         code       start         end  \
# 102  103  Gonzaga Bulldogs - Goalkeeper distributions   339.31459  343.488256
# 103  104                                 Ball in play  343.478256  347.209856
# 104  105                      LMU Lions - Possessions  343.478256  347.209856
# 105  106                LMU Lions - Open play attacks  343.478256  347.209856
# 106  107                                 Ball in play  347.199856  349.774941
# 107  108               Gonzaga Bulldogs - Possessions  347.199856  349.774941
# 118  119  Gonzaga Bulldogs - Goalkeeper distributions  403.868375  445.674434
# 119  120                     Gonzaga Bulldogs - Shots  403.868375  445.674434
# 120  121                                 Ball in play  442.674434  448.088135
# 121  122                      LMU Lions - Possessions  442.674434  448.088135
#
#     01 - Location third 02 - Location flank 03 - End location third  \
# 102           Own third              Center               Own third
# 103         Final third              Center             Final third
# 104         Final third              Center             Final third
# 105         Final third              Center             Final third
# 106           Own third              Center            Middle third
# 107           Own third              Center            Middle third
# 118           Own third         Right flank             Final third
# 119           Own third         Right flank             Final third
# 120           Own third              Center            Middle third
# 121           Own third              Center            Middle third
#
#     04 - End location flank 05 - Length 06 - Number of team events  \
# 102                  Center       Short                  4 or less
# 103                  Center       Short                  4 or less
# 104                  Center       Short                  4 or less
# 105                  Center       Short                  4 or less
# 106              Left flank       Short                  4 or less
# 107              Left flank       Short                  4 or less
# 118                  Center        Long                      10-14
# 119                  Center        Long                      10-14
# 120                  Center       Short                  4 or less
# 121                  Center       Short                  4 or less
#
#      11 - Start location X  12 - Start location Y  13 - Duration  \
# 102                    0.0                   31.0            2.0
# 103                   72.0                   44.0            3.0
# 104                   72.0                   44.0            3.0
# 105                   72.0                   44.0            3.0
# 106                   14.0                   23.0            1.0
# 107                   14.0                   23.0            1.0
# 118                    1.0                   46.0           38.0
# 119                    1.0                   46.0           38.0
# 120                   19.0                   38.0            5.0
# 121                   19.0                   38.0            5.0
#
#     14 - Formation  15 - End location X  16 - End location Y  \
# 102        4-1-4-1                 72.0                 44.0
# 103        4-3-1-2                 14.0                 23.0
# 104        4-3-1-2                 14.0                 23.0
# 105        4-3-1-2                 14.0                 23.0
# 106        4-1-4-1                 64.0                 47.0
# 107        4-1-4-1                 64.0                 47.0
# 118        4-1-4-1                 19.0                 38.0
# 119        4-1-4-1                 19.0                 38.0
# 120        4-3-1-2                 55.0                 31.0
# 121        4-3-1-2                 55.0                 31.0
#
#                                                 10 - Players 08 - Transition  \
# 102                                                 0. Towne             NaN
# 103                                    10. Winter, 9. Groves            High
# 104                                    10. Winter, 9. Groves            High
# 105                                    10. Winter, 9. Groves            High
# 106                                                4. Werner             Low
# 107                                                4. Werner             Low
# 118      0. Towne, 19. Alexander, 21. Rigg, 20. Gray, 13. Le             Low
# 119      0. Towne, 19. Alexander, 21. Rigg, 20. Gray, 13. Le             Low
# 120  6. Watkins, 19. McCulloch, 24. Myklebust, 7. Harrington             Low
# 121  6. Watkins, 19. McCulloch, 24. Myklebust, 7. Harrington             Low
#
#     07 - Outcome        09 - xG
# 102          NaN            NaN
# 103          NaN            NaN
# 104          NaN            NaN
# 105          NaN            NaN
# 106          NaN            NaN
# 107          NaN            NaN
# 118         Shot  less than 0.1
# 119         Shot  less than 0.1
# 120          NaN            NaN
# 121          NaN            NaN

# %%
# Step 1: Filter for Goal kicks by Gonzaga
goal_kicks = player_data[
    (player_data['Action Type'] == 'Goal kick') &
    (player_data['Team'] == 'Gonzaga')
]

# Step 2: Get indices of those rows
goal_kick_indices = goal_kicks.index

# Step 3: Collect each row and the next 5 rows
subset_rows = []

for idx in goal_kick_indices:
    # Get current and next 5 rows (handle end-of-DataFrame edge case)
    next_rows = player_data.loc[idx:idx+5]
    subset_rows.append(next_rows)

# Step 4: Combine all into one DataFrame
goal_kick_sequences = pd.concat(subset_rows).drop_duplicates()

# Optional: sort by original index
goal_kick_sequences = goal_kick_sequences.sort_index()

# Display
goal_kick_sequences
# Out:
#         ID    Player Code   Start Time     End Time   Action Type  \
# 108    109       0. Towne   338.314590   342.314590     Goal kick
# 109    110     10. Winter   340.478256   345.478256          Pass
# 110    111      9. Groves   342.265986   347.265986          Pass
# 111    112     10. Winter   343.124765   348.124765          Pass
# 112    113      4. Werner   344.199856   349.764941          Pass
# 113    114   16. Schaefer   346.764941   352.946336          Pass
# 369    370       0. Towne  1135.814984  1139.814984     Goal kick
# 370    371     10. Winter  1142.166585  1146.166585          Duel
# 371    372  19. Alexander  1142.166585  1146.166585          Duel
# 372    373  19. Alexander  1144.595569  1149.595569          Pass
# 373    374  19. McCulloch  1147.553112  1151.553112         Touch
# 374    375  19. McCulloch  1147.666477  1154.745481          Pass
# 438    439       0. Towne  1318.901559  1322.901559     Goal kick
# 439    440       7. Warta  1321.747072  1325.747072         Touch
# 440    441       7. Warta  1323.482748  1330.828419          Pass
# 441    442     6. Watkins  1328.828419  1332.828419          Duel
# 442    443     11. Garcia  1328.828419  1332.828419          Duel
# 443    444     11. Garcia  1327.646026  1335.646026          Pass
# 709    710       0. Towne  2421.253241  2425.253241     Goal kick
# 710    711     6. Watkins  2422.867690  2426.867690          Duel
# 711    712       7. Warta  2423.210856  2427.210856          Duel
# 712    713       21. Rigg  2424.134210  2430.634649          Pass
# 713    714         13. Le  2427.634649  2434.175933          Pass
# 714    715        2. Chin  2431.175933  2436.175933          Pass
# 781    782       0. Towne  2656.133341  2660.133341     Goal kick
# 782    783      5. Rucker  2658.289901  2662.289901          Duel
# 783    784       23. Land  2658.420213  2663.420213          Pass
# 784    785      9. Groves  2660.396968  2666.544192          Pass
# 785    786     6. Watkins  2663.544192  2668.544192          Pass
# 786    787   16. Schaefer  2665.169325  2671.343674          Pass
# 909    910       0. Towne  3089.553858  3093.553858     Goal kick
# 910    911         13. Le  3091.263131  3095.263131         Touch
# 911    912       23. Land  3092.450248  3096.450248          Duel
# 912    913       23. Land  3093.943086  3098.943086          Pass
# 913    914  19. McCulloch  3094.896121  3099.896121          Pass
# 914    915       4. Dobbs  3096.568387  3101.568387          Pass
# 1196  1197       0. Towne  4033.008115  4037.008115     Goal kick
# 1197  1198       7. Warta  4035.007994  4039.007994          Duel
# 1198  1199      5. Rucker  4035.209472  4039.209472          Duel
# 1199  1200      5. Rucker  4034.750735  4040.930076          Pass
# 1200  1201       20. Gray  4037.930076  4044.504854  Interception
# 1201  1202  24. Myklebust  4041.504854  4048.170396          Pass
# 1384  1385       0. Towne  4769.103780  4773.103780     Goal kick
# 1385  1386        2. Chin  4771.545352  4776.545352          Pass
# 1386  1387      5. Rucker  4773.584916  4777.584916          Duel
# 1387  1388     11. Garcia  4774.634333  4778.634333          Duel
# 1388  1389  19. McCulloch  4774.276686  4780.945763          Pass
# 1389  1390       3. Jones  4775.280598  4779.280598          Duel
#
#                                                                                      Additional Labels  \
# 108                                                                            Goalkeeper action, Loss
# 109                             Forward pass, Recovery, Counterpressing recovery, Short or medium pass
# 110                                                                    Back pass, Short or medium pass
# 111                                     Forward pass, Loss, Pass to penalty area, Short or medium pass
# 112                                         Forward pass, Loss, Progressive pass, Short or medium pass
# 113        Lateral pass, Pass to final third, Recovery, Counterpressing recovery, Short or medium pass
# 369                                                                                  Goalkeeper action
# 370                                                 Defensive duel, Dribbled past attempt, Ground duel
# 371                                                        Dribble, Ground duel, Offensive duel, Carry
# 372                                         Lateral pass, Loss, Progressive pass, Short or medium pass
# 373                                                                                              Carry
# 374                                                                    Back pass, Short or medium pass
# 438                                                                                  Goalkeeper action
# 439                                                                                              Carry
# 440                          Forward pass, Pass to final third, Progressive pass, Short or medium pass
# 441                                                                        Defensive duel, Ground duel
# 442                                       Dribble, Ground duel, Offensive duel, Progressive run, Carry
# 443   Cross, Deep completed cross, Key pass, Lateral pass, Progressive pass, Shot assist, Touch in box
# 709                                                                                  Goalkeeper action
# 710                                                                                        Aerial duel
# 711                                                                                        Aerial duel
# 712                                                                    Back pass, Short or medium pass
# 713                                                                 Lateral pass, Short or medium pass
# 714                                                                 Forward pass, Short or medium pass
# 781                                                                                  Goalkeeper action
# 782                                    Defensive duel, Ground duel, Recovery, Counterpressing recovery
# 783                                                                 Lateral pass, Short or medium pass
# 784                                                                    Back pass, Short or medium pass
# 785                                                                 Lateral pass, Short or medium pass
# 786                                               Lateral pass, Progressive pass, Short or medium pass
# 909                                                                                  Goalkeeper action
# 910
# 911                                                                        Ground duel, Offensive duel
# 912                                                                     Recovery, Short or medium pass
# 913                          Lateral pass, Pass to final third, Progressive pass, Short or medium pass
# 914                                                                               Short or medium pass
# 1196                                                                                 Goalkeeper action
# 1197                                                                 Defensive duel, Ground duel, Loss
# 1198                                                                       Ground duel, Offensive duel
# 1199                                                                        Loss, Short or medium pass
# 1200                                          Forward pass, Long pass, Loss, Pass, Pass to final third
# 1201                                                            Progressive pass, Short or medium pass
# 1384                                                                                 Goalkeeper action
# 1385                                                         Forward pass, Long pass, Progressive pass
# 1386                                                                       Ground duel, Offensive duel
# 1387                                                                                 Aerial duel, Loss
# 1388                         Forward pass, Pass to final third, Progressive pass, Short or medium pass
# 1389                                                                       Defensive duel, Ground duel
#
#          Team
# 108   Gonzaga
# 109       LMU
# 110       LMU
# 111       LMU
# 112   Gonzaga
# 113       LMU
# 369   Gonzaga
# 370       LMU
# 371   Gonzaga
# 372   Gonzaga
# 373       LMU
# 374       LMU
# 438   Gonzaga
# 439   Gonzaga
# 440   Gonzaga
# 441       LMU
# 442   Gonzaga
# 443   Gonzaga
# 709   Gonzaga
# 710       LMU
# 711   Gonzaga
# 712   Gonzaga
# 713   Gonzaga
# 714   Gonzaga
# 781   Gonzaga
# 782       LMU
# 783       LMU
# 784       LMU
# 785       LMU
# 786       LMU
# 909   Gonzaga
# 910   Gonzaga
# 911       LMU
# 912       LMU
# 913       LMU
# 914       LMU
# 1196  Gonzaga
# 1197  Gonzaga
# 1198      LMU
# 1199      LMU
# 1200  Gonzaga
# 1201      LMU
# 1384  Gonzaga
# 1385  Gonzaga
# 1386      LMU
# 1387  Gonzaga
# 1388      LMU
# 1389  Gonzaga

# %%
player_data.head(55)
# Out:
#     ID    Player Code  Start Time    End Time   Action Type  \
# 0    1         13. Le    3.184460    8.184460          Pass
# 1    2       7. Warta    4.770350   11.855952          Pass
# 2    3  19. McCulloch    9.855952   13.855952          Duel
# 3    4     14. Severn    9.855952   13.855952          Duel
# 4    5  19. McCulloch   11.577991   15.577991          Duel
# 5    6     14. Severn   11.577991   15.577991          Duel
# 6    7     14. Severn   17.681888   21.681888      Throw in
# 7    8         13. Le   19.907523   26.613645          Pass
# 8    9       20. Gray   23.613645   29.040995          Pass
# 9   10         13. Le   26.040995   32.643144          Pass
# 10  11     14. Severn   29.643144   34.643144          Pass
# 11  12        2. Chin   30.404975   37.509108          Pass
# 12  13  24. Myklebust   34.509108   39.509108          Pass
# 13  14      5. Rucker   36.322641   40.322641         Touch
# 14  15        2. Chin   41.309912   45.309912      Throw in
# 15  16       21. Rigg   42.110298   46.110298         Touch
# 16  17      5. Rucker   43.317207   47.317207          Duel
# 17  18       21. Rigg   43.450456   47.450456          Duel
# 18  19      5. Rucker   45.871635   49.871635          Duel
# 19  20     14. Severn   46.216743   50.216743          Duel
# 20  21         13. Le   49.077071   54.497946          Pass
# 21  22  19. Alexander   52.497946   56.497946         Touch
# 22  23  19. Alexander   51.028438   70.935364          Pass
# 23  24      1. Hoover   56.536032   60.536032         Touch
# 24  25      1. Hoover   67.935364   73.832997          Pass
# 25  26       20. Gray   71.832997   75.832997          Duel
# 26  27       4. Dobbs   71.832997   75.832997          Duel
# 27  28     10. Winter   74.644369   80.397315          Pass
# 28  29   16. Schaefer   77.397315   82.397315          Pass
# 29  30     11. Garcia   79.317593   83.317593  Interception
# 30  31   16. Schaefer   80.738850   86.282175          Pass
# 31  32      9. Groves   83.282175   89.677792          Pass
# 32  33      5. Rucker   86.677792   91.677792          Pass
# 33  34  19. McCulloch   87.746046   92.746046          Pass
# 34  35     14. Severn   89.255991   93.255991  Interception
# 35  36  19. McCulloch   90.563348   99.620373          Pass
# 36  37  19. Alexander   96.620373  101.658428          Pass
# 37  38      4. Werner   98.658428  103.658428          Pass
# 38  39       7. Warta  101.151067  105.151067         Touch
# 39  40       7. Warta  102.168281  107.168281          Pass
# 40  41       21. Rigg  104.391928  108.391928         Touch
# 41  42       23. Land  104.314099  109.439822          Pass
# 42  43  24. Myklebust  106.439822  112.943083          Pass
# 43  44     10. Winter  109.943083  114.943083          Pass
# 44  45  19. Alexander  111.712048  115.712048  Interception
# 45  46  7. Harrington  114.968618  118.968618          Duel
# 46  47      4. Werner  115.081821  119.081821          Duel
# 47  48  7. Harrington  111.152133  125.152133          Shot
# 48  49       0. Towne  118.896446  122.896446  Shot against
# 49  50  24. Myklebust  152.218700  167.218700        Corner
# 50  51      4. Werner  155.394452  159.394452          Duel
# 51  52      5. Rucker  155.626779  160.626779          Pass
# 52  53       23. Land  158.173250  162.173250          Duel
# 53  54       23. Land  158.512281  163.512281          Pass
# 54  55  24. Myklebust  157.277808  165.277808          Pass
#
#                                                                                                 Additional Labels  \
# 0                                                                              Forward pass, Short or medium pass
# 1                                                         Lateral pass, Pass to final third, Short or medium pass
# 2                                                                           Defensive duel, Ground duel, Recovery
# 3                                                                               Ground duel, Loss, Offensive duel
# 4                                                                                     Ground duel, Offensive duel
# 5                                                                                     Defensive duel, Ground duel
# 6
# 7                                                                              Lateral pass, Short or medium pass
# 8                                                                              Lateral pass, Short or medium pass
# 9                                                                                 Back pass, Short or medium pass
# 10                                                                                           Short or medium pass
# 11                                                             Forward pass, Long pass, Loss, Pass to final third
# 12                                                                                 Recovery, Short or medium pass
# 13
# 14
# 15                                                                                                    Loss, Carry
# 16                                                Defensive duel, Ground duel, Recovery, Counterpressing recovery
# 17                                                                                    Ground duel, Offensive duel
# 18                                                                     Dribble, Ground duel, Loss, Offensive duel
# 19                                                Defensive duel, Ground duel, Recovery, Counterpressing recovery
# 20                                                                             Lateral pass, Short or medium pass
# 21                                                                                         Progressive run, Carry
# 22                                                                Cross, Lateral pass, Loss, Pass to penalty area
# 23                                                                                       Goalkeeper action, Carry
# 24                                                   Forward pass, Goalkeeper action, Long pass, Progressive pass
# 25                                                                                                Loose ball duel
# 26                                                                                                Loose ball duel
# 27                                                                                           Short or medium pass
# 28                                                                   Loss, Progressive pass, Short or medium pass
# 29                                                                                                 Loss, Recovery
# 30                                         Forward pass, Recovery, Counterpressing recovery, Short or medium pass
# 31                                                                             Lateral pass, Short or medium pass
# 32                                      Forward pass, Pass to final third, Progressive pass, Short or medium pass
# 33                                                                Forward pass, Loss, Carry, Short or medium pass
# 34                                                                                                 Loss, Recovery
# 35                                                        Lateral pass, Pass to final third, Short or medium pass
# 36                                                                                 Recovery, Short or medium pass
# 37                                                                             Forward pass, Short or medium pass
# 38                                                                                                          Carry
# 39                                      Forward pass, Pass to final third, Progressive pass, Short or medium pass
# 40                                                                                                           Loss
# 41                                                                      Back pass, Recovery, Short or medium pass
# 42                                                                             Lateral pass, Short or medium pass
# 43                                                                       Forward pass, Loss, Short or medium pass
# 44                                                                                                 Loss, Recovery
# 45                                         Ground duel, Offensive duel, Recovery, Counterpressing recovery, Carry
# 46                                                                                    Defensive duel, Ground duel
# 47                                                                                                    Opportunity
# 48                                                                                        Goalkeeper action, Save
# 49
# 50                                                                                              Aerial duel, Loss
# 51  Deep completion, Forward pass, Pass to penalty area, Recovery, Counterpressing recovery, Short or medium pass
# 52                                                                             Ground duel, Offensive duel, Carry
# 53                                                               Lateral pass, Short or medium pass, Touch in box
# 54                                                                                           Cross, Cross blocked
#
#        Team
# 0   Gonzaga
# 1   Gonzaga
# 2       LMU
# 3   Gonzaga
# 4       LMU
# 5   Gonzaga
# 6   Gonzaga
# 7   Gonzaga
# 8   Gonzaga
# 9   Gonzaga
# 10  Gonzaga
# 11  Gonzaga
# 12      LMU
# 13      LMU
# 14  Gonzaga
# 15  Gonzaga
# 16      LMU
# 17  Gonzaga
# 18      LMU
# 19  Gonzaga
# 20  Gonzaga
# 21  Gonzaga
# 22  Gonzaga
# 23      LMU
# 24      LMU
# 25  Gonzaga
# 26      LMU
# 27      LMU
# 28      LMU
# 29  Gonzaga
# 30      LMU
# 31      LMU
# 32      LMU
# 33      LMU
# 34  Gonzaga
# 35      LMU
# 36  Gonzaga
# 37  Gonzaga
# 38  Gonzaga
# 39  Gonzaga
# 40  Gonzaga
# 41      LMU
# 42      LMU
# 43      LMU
# 44  Gonzaga
# 45      LMU
# 46  Gonzaga
# 47      LMU
# 48  Gonzaga
# 49      LMU
# 50  Gonzaga
# 51      LMU
# 52      LMU
# 53      LMU
# 54      LMU

# %%
# Draw the pitch
pitch = Pitch(pitch_type='statsbomb', pitch_color='#195905', line_color='white')
fig, ax = pitch.draw(figsize=(12, 8))

# Filter Hoover's goalkeeper passes
hoover_passes = player_data[
    (player_data['Player Code'] == '0. Towne') &
    (player_data['Action Type'].isin(['Goalkeeper action', 'Goal kick', 'Pass']))
].dropna(subset=['15 - End location X', '16 - End location Y'])

# Loop through each Hoover pass
for idx in hoover_passes.index:
    # First arrow: Hoover to receiver
    start1_x = hoover_passes.loc[idx, '11 - Start location X']
    start1_y = hoover_passes.loc[idx, '12 - Start location Y']
    end1_x = hoover_passes.loc[idx, '15 - End location X']
    end1_y = hoover_passes.loc[idx, '16 - End location Y']
    
    pitch.arrows(start1_x, start1_y, end1_x, end1_y,
                 color='yellow', ax=ax, width=2, headwidth=4, alpha=0.8, zorder=3)

    # Second arrow: receiver's next action
    try:
        next1 = player_data.loc[idx + 1]
        start2_x = next1['11 - Start location X']
        start2_y = next1['12 - Start location Y']
        end2_x = next1['15 - End location X']
        end2_y = next1['16 - End location Y']

        if pd.notna(end2_x) and pd.notna(end2_y):
            pitch.arrows(start2_x, start2_y, end2_x, end2_y,
                         color='orange', ax=ax, width=2, headwidth=4, alpha=0.8, zorder=3)

        # Third arrow: next action after that
        next2 = player_data.loc[idx + 2]
        start3_x = next2['11 - Start location X']
        start3_y = next2['12 - Start location Y']
        end3_x = next2['15 - End location X']
        end3_y = next2['16 - End location Y']

        if pd.notna(end3_x) and pd.notna(end3_y):
            pitch.arrows(start3_x, start3_y, end3_x, end3_y,
                         color='red', ax=ax, width=2, headwidth=4, alpha=0.8, zorder=3)

    except Exception as e:
        # Handles end-of-DataFrame or missing values
        continue

plt.title("Gonzaga GK Hoover Distribution & Follow-up Sequences", fontsize=16, color='white')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/hd/fbf93pws5pn1ycb22tw5k1240000gn/T/ipykernel_57286/3946922275.py in ?()
#       5 # Filter Hoover's goalkeeper passes
#       6 hoover_passes = player_data[
#       7     (player_data['Player Code'] == '0. Towne') &
#       8     (player_data['Action Type'].isin(['Goalkeeper action', 'Goal kick', 'Pass']))
# ----> 9 ].dropna(subset=['15 - End location X', '16 - End location Y'])
#      10
#      11 # Loop through each Hoover pass
#      12 for idx in hoover_passes.index:
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['15 - End location X', '16 - End location Y']
